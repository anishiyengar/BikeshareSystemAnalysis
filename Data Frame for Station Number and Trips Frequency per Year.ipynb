# %%
# This code finds the amount of unique stations from each data set since there is no data set for number of stations in each year

# %%
import pandas as pd
import matplotlib.pyplot as plt


data = {'Rides per Year':[14097,530375,906877,1050724,1080398,1236215],'Number of Stations':[61,108,130,140,151,187], '% Change in Rides per Year': ['n/a', 276.2191878,70.98788593,15.86179824,2.824147921,14.42218516], '% Change in Number of Stations per Year': ['n/a', 77.04918,20.037037,7.692308,7.857143,24.503311]}
df = pd.DataFrame(data, index=['2011','2012','2013','2014','2015','2016'])
df.style.apply
print(df)

year = [2011,2012,2013,2014,2015,2016]
change_rides = [0, 276.2191878, 70.98788593, 15.86179824, 2.824147921, 14.42218516]
change_stations = [0,77.04918, 20.037037, 7.692308, 7.857143, 24.503311]
plt.plot(year, change_rides, color='g')
plt.plot(year, change_stations, color='orange')
plt.xlabel('Year')
plt.ylabel('(&) Percent Change')
plt.title('Percent Change in # of Stations and Rides')
plt.show()
# Out:
#      % Change in Number of Stations per Year % Change in Rides per Year  \
# 2011                                     n/a                        n/a
# 2012                                 77.0492                    276.219
# 2013                                  20.037                    70.9879
# 2014                                 7.69231                    15.8618
# 2015                                 7.85714                    2.82415
# 2016                                 24.5033                    14.4222
#
#       Number of Stations  Rides per Year
# 2011                  61           14097
# 2012                 108          530375
# 2013                 130          906877
# 2014                 140         1050724
# 2015                 151         1080398
# 2016                 187         1236215
